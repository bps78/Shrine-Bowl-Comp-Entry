# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np

# %%
#Import data
shrine_players = pd.read_parquet('data/shrine_bowl_players.parquet', engine='fastparquet')
college_stats = pd.read_csv('data/shrine_bowl_players_college_stats.csv')
nfl_stats = pd.read_csv('data/shrine_bowl_players_nfl_rookie_stats.csv')
sos_stats = pd.read_csv('data/sos_data.csv')

shrine_players.head()
# Out:
#   gsis_player_id first_name   last_name football_name weight hand_size  \
# 0         350698     Dwight  McGlothern        Dwight  189.0       8.5
# 1         336849     Hunter     Nourzad        Hunter  319.0     10.75
# 2         362959      Jaden     Shirden         Jaden  189.0      9.25
# 3         324852      David    Ugwoegbu         David  243.0     10.25
# 4         304792     Ernest       Perry          E.J.  208.0       9.0
#
#   last_twenty_of_forty_yd_dash first_ten_of_forty_yd_dash standing_broad_jump  \
# 0                    1.8699999                       1.55               111.0
# 1                         None                       None                None
# 2                    1.8799999                       1.56               117.0
# 3                         1.97                       1.75               116.0
# 4                         1.99                       1.58               123.0
#
#   three_cone  ... draft_round draft_pick draft_overall_selection    hometown  \
# 0       7.23  ...        None       None                    None     Houston
# 1       None  ...           5         24                     160    Marietta
# 2       None  ...        None       None                    None  West Haven
# 3       7.56  ...        None       None                    None        Katy
# 4       6.85  ...        None       None                    None     Andover
#
#   hometown_state hometown_country recruiting_stars team_code  \
# 0             TX               US                4      ARUN
# 1             GA               US             None      PAST
# 2             CT               US             None      NJMO
# 3             TX               US                3      TXHO
# 4             MA               US                3      RIBR
#
#                   team_name                     conference
# 0       Arkansas Razorbacks        Southeastern Conference
# 1  Penn State Nittany Lions             Big Ten Conference
# 2            Monmouth Hawks  Colonial Athletic Association
# 3           Houston Cougars          Big Twelve Conference
# 4               Brown Bears                     Ivy League
#
# [5 rows x 33 columns]

# %%
college_stats.head()
# Out:
#    college_gsis_id position     player_name  season team school_code  \
# 0           158332       DT  Garrett Marino    2017  UAB        ALBI
# 1           158332       DT  Garrett Marino    2018  UAB        ALBI
# 2           158332       DT  Garrett Marino    2019  UAB        ALBI
# 3           172387       DS      Austin Lee    2017  BYU        UTBY
# 4           172387       DS      Austin Lee    2018  BYU        UTBY
#
#    passing_attempts  passing_completions  passing_yards  \
# 0               NaN                  NaN            NaN
# 1               NaN                  NaN            NaN
# 2               NaN                  NaN            NaN
# 3               NaN                  NaN            NaN
# 4               1.0                  0.0            0.0
#
#    passing_completion_percentage  ...  kickreturns_no  kickreturns_touchdowns  \
# 0                            NaN  ...             NaN                     NaN
# 1                            NaN  ...             NaN                     NaN
# 2                            NaN  ...             NaN                     NaN
# 3                            NaN  ...             NaN                     NaN
# 4                            0.0  ...             NaN                     NaN
#
#    kickreturns_yards  puntreturns_avg  puntreturns_long  puntreturns_no  \
# 0                NaN              NaN               NaN             NaN
# 1                NaN              NaN               NaN             NaN
# 2                NaN              NaN               NaN             NaN
# 3                NaN              NaN               NaN             NaN
# 4                NaN              NaN               NaN             NaN
#
#    puntreturns_td  puntreturns_yds  total_fumbles  total_fumbles_lost
# 0             NaN              NaN            0.0                 0.0
# 1             NaN              NaN            0.0                 0.0
# 2             NaN              NaN            0.0                 0.0
# 3             NaN              NaN            0.0                 0.0
# 4             NaN              NaN            NaN                 NaN
#
# [5 rows x 38 columns]

# %%
nfl_stats.head()
# Out:
#    college_gsis_id  rookie_season     player_name position  draft_season  \
# 0           196601           2020    Khalil Davis       DT          2020
# 1           305707           2024     Dallas Gant       IB          2024
# 2           316846           2023      Moro Ojomo       DT          2023
# 3           196251           2020  Alex Highsmith       DE          2020
# 4           282907           2022    Samori Toure       WR          2022
#
#    draft_round  draft_overall_selection  scrambles  qb_pressures  \
# 0          6.0                    194.0        NaN           NaN
# 1          NaN                      NaN        NaN           NaN
# 2          7.0                    249.0        NaN           NaN
# 3          3.0                    102.0        NaN           NaN
# 4          7.0                    258.0        NaN           NaN
#
#    qb_pressure_to_sack_rate  ...  rushing_yards  rushing_touchdowns  \
# 0                       NaN  ...            NaN                 NaN
# 1                       NaN  ...            NaN                 NaN
# 2                       NaN  ...            NaN                 NaN
# 3                       NaN  ...            NaN                 NaN
# 4                       NaN  ...            NaN                 NaN
#
#    receiving_targets  receiving_receptions  receiving_yards  \
# 0                NaN                   NaN              NaN
# 1                NaN                   NaN              NaN
# 2                NaN                   NaN              NaN
# 3                NaN                   NaN              NaN
# 4               10.0                   5.0             82.0
#
#    receiving_yards_per_route_run  receiving_touchdowns  \
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                       1.108108                   1.0
#
#    receiving_yards_after_catch  defense_interceptions  defense_pass_breakups
# 0                          NaN                    NaN                    NaN
# 1                          NaN                    NaN                    NaN
# 2                          NaN                    NaN                    NaN
# 3                          NaN                    1.0                    1.0
# 4                         11.0                    NaN                    NaN
#
# [5 rows x 43 columns]

# %%
sos_stats.head()
# Out:
#    Rank      Team  Rating  Hi  Lo  Last  Year
# 0     1  Indiana     17.3   1  68     2  2025
# 1     2  Ohio St     16.0   2  18    14  2025
# 2     3  Alabama     15.5   1  21     1  2025
# 3     4   Oregon     15.4   1  71     3  2025
# 4     5    Texas     13.8   1  20     8  2025

# %%
print(college_stats.columns)
print(college_stats['position'].unique())
# Out:
# Index(['college_gsis_id', 'position', 'player_name', 'season', 'team',
#        'school_code', 'passing_attempts', 'passing_completions',
#        'passing_yards', 'passing_completion_percentage', 'passing_touchdowns',
#        'passing_interceptions', 'rushing_attempts', 'rushing_yards',
#        'rushing_touchdowns', 'receiving_receptions', 'receiving_touchdowns',
#        'receiving_yards', 'defense_pass_breakups', 'defense_qb_hurries',
#        'defense_sacks', 'defense_solo_tackles', 'defense_total_tackles',
#        'defense_tackles_for_loss', 'defense_interceptions',
#        'defense_touchdowns', 'kickreturns_avg', 'kickreturns_long',
#        'kickreturns_no', 'kickreturns_touchdowns', 'kickreturns_yards',
#        'puntreturns_avg', 'puntreturns_long', 'puntreturns_no',
#        'puntreturns_td', 'puntreturns_yds', 'total_fumbles',
#        'total_fumbles_lost'],
#       dtype='object')
# ['DT' 'DS' 'WR' 'DC' 'QB' 'DE' 'RB' 'OB' 'IB' 'OG' 'TE' 'OT' 'OC' 'FB']

# %%
college_wr = college_stats[college_stats['position'] == 'WR']
college_qb = college_stats[college_stats['position'] == 'QB']
college_te = college_stats[college_stats['position'] == 'TE']
college_fb = college_stats[college_stats['position'] == 'FB']
college_rb = college_stats[college_stats['position'] == 'RB']
college_db = college_stats[college_stats['position'] == 'DB']
